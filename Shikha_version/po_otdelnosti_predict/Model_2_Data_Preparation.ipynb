# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Импорт необходимых библиотек и модулей

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Скачиваем набор данных

# %%
# Change directory for kaggle JSON
import os
os.chdir("/content/drive/MyDrive/files")

# %%
# Create a kaggle folder
# !mkdir -p ~/.kaggle

# Copy kaggle.json to created folder
# !cp kaggle.json ~/.kaggle/

# %%
os.chdir("/content")

# %%
# Permission for the json to act
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# Download the required dataset
# !kaggle datasets download -d raddar/chest-xrays-indiana-university
# Out:
# Downloading chest-xrays-indiana-university.zip to /content
# 100% 13.2G/13.2G [02:16<00:00, 101MB/s]
# 100% 13.2G/13.2G [02:16<00:00, 104MB/s]

# %%
# Unzip our dataset
from zipfile import ZipFile
from tqdm import tqdm


file_to_extract = "chest-xrays-indiana-university.zip"

# Open your .zip file
with ZipFile(file=file_to_extract) as zip_file:

    # Loop over each file and extract them
    for file in tqdm(iterable=zip_file.namelist(), total=len(zip_file.namelist())):
        zip_file.extract(member=file)
# Out:
# 100%|██████████| 7472/7472 [02:55<00:00, 42.66it/s]

# %% [markdown]
# ## Загрузка модели

# %%
df_1 = pd.read_csv('/content/indiana_reports.csv')
df_1.head()
# Out:
#    uid                                               MeSH  \
# 0    1                                             normal
# 1    2  Cardiomegaly/borderline;Pulmonary Artery/enlarged
# 2    3                                             normal
# 3    4  Pulmonary Disease, Chronic Obstructive;Bullous...
# 4    5  Osteophyte/thoracic vertebrae/multiple/small;T...
#
#                                             Problems  \
# 0                                             normal
# 1                      Cardiomegaly;Pulmonary Artery
# 2                                             normal
# 3  Pulmonary Disease, Chronic Obstructive;Bullous...
# 4                         Osteophyte;Thickening;Lung
#
#                                                image  \
# 0                          Xray Chest PA and Lateral
# 1                Chest, 2 views, frontal and lateral
# 2                          Xray Chest PA and Lateral
# 3  PA and lateral views of the chest XXXX, XXXX a...
# 4                          Xray Chest PA and Lateral
#
#                                           indication      comparison  \
# 0                                   Positive TB test           None.
# 1                           Preop bariatric surgery.           None.
# 2  rib pain after a XXXX, XXXX XXXX steps this XX...             NaN
# 3                      XXXX-year-old XXXX with XXXX.  None available
# 4                        Chest and nasal congestion.             NaN
#
#                                             findings  \
# 0  The cardiac silhouette and mediastinum size ar...
# 1  Borderline cardiomegaly. Midline sternotomy XX...
# 2                                                NaN
# 3  There are diffuse bilateral interstitial and a...
# 4  The cardiomediastinal silhouette and pulmonary...
#
#                                           impression
# 0                               Normal chest x-XXXX.
# 1                       No acute pulmonary findings.
# 2  No displaced rib fractures, pneumothorax, or p...
# 3  1. Bullous emphysema and interstitial fibrosis...
# 4              No acute cardiopulmonary abnormality.

# %%
df_2 = pd.read_csv('/content/indiana_projections.csv')
df_2.head()
# Out:
#    uid                filename projection
# 0    1  1_IM-0001-4001.dcm.png    Frontal
# 1    1  1_IM-0001-3001.dcm.png    Lateral
# 2    2  2_IM-0652-1001.dcm.png    Frontal
# 3    2  2_IM-0652-2001.dcm.png    Lateral
# 4    3  3_IM-1384-1001.dcm.png    Frontal

# %%
df = pd.merge(df_1, df_2, on='uid')
df.shape
# Out:
# (7466, 10)

# %%
df.isnull().sum()
# Out:
# uid              0
# MeSH             0
# Problems         0
# image            0
# indication     159
# comparison    1157
# findings       997
# impression      52
# filename         0
# projection       0
# dtype: int64

# %% [markdown]
# ## Обработка текстовых данных

# %%
import string
import regex as re
import nltk
from nltk.tokenize import word_tokenize

# %%
nltk.download('stopwords')
from nltk.corpus import stopwords
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# Уберем сокращения

# %%
def decontraction(doc):
    docs = re.sub(r"won't", "will not", doc)
    docs = re.sub(r"can\'t", "can not", docs)
    docs = re.sub(r"n\'t", " not", docs)
    docs = re.sub(r"\'t", " not", docs)
    docs = re.sub(r"\'re", " are", docs)
    docs = re.sub(r"\'s", " is", docs)
    docs = re.sub(r"\'d", " would", docs)
    docs = re.sub(r"\'ve", " have", docs)
    docs = re.sub(r"\'ll", " will", docs)
    docs = re.sub(r"\'m", " am", docs)
    docs = re.sub(r"\*+", "abuse", docs)
    return docs

# %%
def remove_stopwords(data):
    all_stopwords = stopwords.words('english')
    all_stopwords.remove('not')  # removing the "not" from the stopwords
    all_stopwords.remove('no')
    text_tokens = word_tokenize(data)  # tokenizing the sentence into word
    tokens_without_sw = [word for word in text_tokens if not word in all_stopwords]
    return " ".join(tokens_without_sw)

# %%
def text_preprocess(data):
    text = str(data)

    # making the text in lower case
    text = text.lower()

    # removing the special character in text
    text = re.sub(r"[|\'||\||/|?|$|.|.|,||;|><!&)(:`\n\t@#=+%^*~-]", "" , text)

    # Removing the irrelavent XXXX words
    text = re.sub(r'x+', "", text)

    # Removing the numbers in text
    text = re.sub(r'[0-9]', "", text)
    text = re.sub(r"yearold", "", text)
    text = re.sub('\s+', " ", text)

    # Removing apoustahe
    text = re.sub("'", "", text)

    # Removing multiple full stop
    text = re.sub(r'\.\.+', '.', text)
    text = re.sub(r'  ', "", text)

    text = decontraction(text)

    return text

# %%
df["indication"] = df["indication"].apply(lambda x:text_preprocess(x))
df["findings"] = df["findings"].apply(lambda x:text_preprocess(x))
df["impression"] = df["impression"].apply(lambda x:text_preprocess(x))

# %%
df.head()
# Out:
#    uid                                               MeSH  \
# 0    1                                             normal
# 1    1                                             normal
# 2    2  Cardiomegaly/borderline;Pulmonary Artery/enlarged
# 3    2  Cardiomegaly/borderline;Pulmonary Artery/enlarged
# 4    3                                             normal
#
#                         Problems                                image  \
# 0                         normal            Xray Chest PA and Lateral
# 1                         normal            Xray Chest PA and Lateral
# 2  Cardiomegaly;Pulmonary Artery  Chest, 2 views, frontal and lateral
# 3  Cardiomegaly;Pulmonary Artery  Chest, 2 views, frontal and lateral
# 4                         normal            Xray Chest PA and Lateral
#
#                                           indication comparison  \
# 0                                   positive tb test      None.
# 1                                   positive tb test      None.
# 2                            preop bariatric surgery      None.
# 3                            preop bariatric surgery      None.
# 4  rib pain after a steps this pain to r back r e...        NaN
#
#                                             findings  \
# 0  the cardiac silhouette and mediastinum size ar...
# 1  the cardiac silhouette and mediastinum size ar...
# 2  borderline cardiomegaly midline sternotomy enl...
# 3  borderline cardiomegaly midline sternotomy enl...
# 4                                                nan
#
#                                           impression                filename  \
# 0                                      normal chest   1_IM-0001-4001.dcm.png
# 1                                      normal chest   1_IM-0001-3001.dcm.png
# 2                        no acute pulmonary findings  2_IM-0652-1001.dcm.png
# 3                        no acute pulmonary findings  2_IM-0652-2001.dcm.png
# 4  no displaced rib fractures pneumothora or pleu...  3_IM-1384-1001.dcm.png
#
#   projection
# 0    Frontal
# 1    Lateral
# 2    Frontal
# 3    Lateral
# 4    Frontal

# %% [markdown]
# ## Сгруппируем изображения

# %%
frontal_df = df[df['projection']=='Frontal']
frontal_df.head()
# Out:
#    uid                                               MeSH  \
# 0    1                                             normal
# 2    2  Cardiomegaly/borderline;Pulmonary Artery/enlarged
# 4    3                                             normal
# 6    4  Pulmonary Disease, Chronic Obstructive;Bullous...
# 8    5  Osteophyte/thoracic vertebrae/multiple/small;T...
#
#                                             Problems  \
# 0                                             normal
# 2                      Cardiomegaly;Pulmonary Artery
# 4                                             normal
# 6  Pulmonary Disease, Chronic Obstructive;Bullous...
# 8                         Osteophyte;Thickening;Lung
#
#                                                image  \
# 0                          Xray Chest PA and Lateral
# 2                Chest, 2 views, frontal and lateral
# 4                          Xray Chest PA and Lateral
# 6  PA and lateral views of the chest XXXX, XXXX a...
# 8                          Xray Chest PA and Lateral
#
#                                           indication      comparison  \
# 0                                   positive tb test           None.
# 2                            preop bariatric surgery           None.
# 4  rib pain after a steps this pain to r back r e...             NaN
# 6                                              with   None available
# 8                         chest and nasal congestion             NaN
#
#                                             findings  \
# 0  the cardiac silhouette and mediastinum size ar...
# 2  borderline cardiomegaly midline sternotomy enl...
# 4                                                nan
# 6  there are diffuse bilateral interstitial and a...
# 8  the cardiomediastinal silhouette and pulmonary...
#
#                                           impression  \
# 0                                      normal chest
# 2                        no acute pulmonary findings
# 4  no displaced rib fractures pneumothora or pleu...
# 6   bullous emphysema and interstitial fibrosis p...
# 8               no acute cardiopulmonary abnormality
#
#                     filename projection
# 0     1_IM-0001-4001.dcm.png    Frontal
# 2     2_IM-0652-1001.dcm.png    Frontal
# 4     3_IM-1384-1001.dcm.png    Frontal
# 6     4_IM-2050-1001.dcm.png    Frontal
# 8  5_IM-2117-1003002.dcm.png    Frontal

# %%
lateral_df = df[df['projection']=='Lateral']
lateral_df.head()
# Out:
#    uid                                               MeSH  \
# 1    1                                             normal
# 3    2  Cardiomegaly/borderline;Pulmonary Artery/enlarged
# 5    3                                             normal
# 7    4  Pulmonary Disease, Chronic Obstructive;Bullous...
# 9    5  Osteophyte/thoracic vertebrae/multiple/small;T...
#
#                                             Problems  \
# 1                                             normal
# 3                      Cardiomegaly;Pulmonary Artery
# 5                                             normal
# 7  Pulmonary Disease, Chronic Obstructive;Bullous...
# 9                         Osteophyte;Thickening;Lung
#
#                                                image  \
# 1                          Xray Chest PA and Lateral
# 3                Chest, 2 views, frontal and lateral
# 5                          Xray Chest PA and Lateral
# 7  PA and lateral views of the chest XXXX, XXXX a...
# 9                          Xray Chest PA and Lateral
#
#                                           indication      comparison  \
# 1                                   positive tb test           None.
# 3                            preop bariatric surgery           None.
# 5  rib pain after a steps this pain to r back r e...             NaN
# 7                                              with   None available
# 9                         chest and nasal congestion             NaN
#
#                                             findings  \
# 1  the cardiac silhouette and mediastinum size ar...
# 3  borderline cardiomegaly midline sternotomy enl...
# 5                                                nan
# 7  there are diffuse bilateral interstitial and a...
# 9  the cardiomediastinal silhouette and pulmonary...
#
#                                           impression  \
# 1                                      normal chest
# 3                        no acute pulmonary findings
# 5  no displaced rib fractures pneumothora or pleu...
# 7   bullous emphysema and interstitial fibrosis p...
# 9               no acute cardiopulmonary abnormality
#
#                     filename projection
# 1     1_IM-0001-3001.dcm.png    Lateral
# 3     2_IM-0652-2001.dcm.png    Lateral
# 5     3_IM-1384-2001.dcm.png    Lateral
# 7     4_IM-2050-2001.dcm.png    Lateral
# 9  5_IM-2117-1004003.dcm.png    Lateral

# %%
image_list = []

for i, ind in zip(frontal_df['uid'], frontal_df['uid'].index) :
    k = lateral_df[lateral_df['uid'] == i]['filename'].values
    for j in range(len(k)) :
        L = []
        L.append(frontal_df['filename'][ind])
        L.append(k[j])
        L.append(frontal_df['MeSH'][ind])
        L.append(frontal_df['Problems'][ind])
        L.append(frontal_df['indication'][ind])
        L.append(frontal_df['findings'][ind])
        L.append(frontal_df['impression'][ind])
        image_list.append(L)
    if len(k) == 0 :
        L = []
        L.append(frontal_df['filename'][ind])
        L.append(frontal_df['filename'][ind])
        L.append(frontal_df['MeSH'][ind])
        L.append(frontal_df['Problems'][ind])
        L.append(frontal_df['indication'][ind])
        L.append(frontal_df['findings'][ind])
        L.append(frontal_df['impression'][ind])
        image_list.append(L)

# %%
columns_in_new_df = ['Frontal', 'Lateral', 'MeSH', 'Problems', 'indication', 'findings', 'impression']
new_df = pd.DataFrame(image_list,columns=columns_in_new_df)
new_df.head()
# Out:
#                      Frontal                    Lateral  \
# 0     1_IM-0001-4001.dcm.png     1_IM-0001-3001.dcm.png
# 1     2_IM-0652-1001.dcm.png     2_IM-0652-2001.dcm.png
# 2     3_IM-1384-1001.dcm.png     3_IM-1384-2001.dcm.png
# 3     4_IM-2050-1001.dcm.png     4_IM-2050-2001.dcm.png
# 4  5_IM-2117-1003002.dcm.png  5_IM-2117-1004003.dcm.png
#
#                                                 MeSH  \
# 0                                             normal
# 1  Cardiomegaly/borderline;Pulmonary Artery/enlarged
# 2                                             normal
# 3  Pulmonary Disease, Chronic Obstructive;Bullous...
# 4  Osteophyte/thoracic vertebrae/multiple/small;T...
#
#                                             Problems  \
# 0                                             normal
# 1                      Cardiomegaly;Pulmonary Artery
# 2                                             normal
# 3  Pulmonary Disease, Chronic Obstructive;Bullous...
# 4                         Osteophyte;Thickening;Lung
#
#                                           indication  \
# 0                                   positive tb test
# 1                            preop bariatric surgery
# 2  rib pain after a steps this pain to r back r e...
# 3                                              with
# 4                         chest and nasal congestion
#
#                                             findings  \
# 0  the cardiac silhouette and mediastinum size ar...
# 1  borderline cardiomegaly midline sternotomy enl...
# 2                                                nan
# 3  there are diffuse bilateral interstitial and a...
# 4  the cardiomediastinal silhouette and pulmonary...
#
#                                           impression
# 0                                      normal chest
# 1                        no acute pulmonary findings
# 2  no displaced rib fractures pneumothora or pleu...
# 3   bullous emphysema and interstitial fibrosis p...
# 4               no acute cardiopulmonary abnormality

# %%
new_df.shape
# Out:
# (3913, 7)

# %% [markdown]
# Заменит строковые Nan на np.nan

# %%
new_df['findings'] = new_df['findings'].replace('nan', np.nan)
new_df['indication'] = new_df['indication'].replace('nan', np.nan)
new_df['impression'] = new_df['impression'].replace('nan', np.nan)

# %%
new_df.isnull().sum()
# Out:
# Frontal         0
# Lateral         0
# MeSH            0
# Problems        0
# indication     88
# findings      525
# impression     31
# dtype: int64

# %%
new_df.to_csv('/content/drive/MyDrive/shikha version/data/final.csv', index=False)

# %%
pd.read_csv('/content/drive/MyDrive/shikha version/data/final.csv')
# Out:
#                         Frontal                    Lateral  \
# 0        1_IM-0001-4001.dcm.png     1_IM-0001-3001.dcm.png
# 1        2_IM-0652-1001.dcm.png     2_IM-0652-2001.dcm.png
# 2        3_IM-1384-1001.dcm.png     3_IM-1384-2001.dcm.png
# 3        4_IM-2050-1001.dcm.png     4_IM-2050-2001.dcm.png
# 4     5_IM-2117-1003002.dcm.png  5_IM-2117-1004003.dcm.png
# ...                         ...                        ...
# 3908  3995_IM-2046-1001.dcm.png  3995_IM-2046-2001.dcm.png
# 3909  3996_IM-2047-1001.dcm.png  3996_IM-2047-3001.dcm.png
# 3910  3997_IM-2048-1001.dcm.png  3997_IM-2048-1002.dcm.png
# 3911  3998_IM-2048-1001.dcm.png  3998_IM-2048-1002.dcm.png
# 3912  3999_IM-2049-1001.dcm.png  3999_IM-2049-2001.dcm.png
#
#                                                    MeSH  \
# 0                                                normal
# 1     Cardiomegaly/borderline;Pulmonary Artery/enlarged
# 2                                                normal
# 3     Pulmonary Disease, Chronic Obstructive;Bullous...
# 4     Osteophyte/thoracic vertebrae/multiple/small;T...
# ...                                                 ...
# 3908  Lung/hyperdistention/mild;Diaphragm/bilateral/...
# 3909                                 Spine/degenerative
# 3910  Opacity/lung/upper lobe/right/round/small;Gran...
# 3911                                             normal
# 3912                                             normal
#
#                                                Problems  \
# 0                                                normal
# 1                         Cardiomegaly;Pulmonary Artery
# 2                                                normal
# 3     Pulmonary Disease, Chronic Obstructive;Bullous...
# 4                            Osteophyte;Thickening;Lung
# ...                                                 ...
# 3908  Lung;Diaphragm;Cicatrix;Pulmonary Atelectasis;...
# 3909                                              Spine
# 3910                                  Opacity;Granuloma
# 3911                                             normal
# 3912                                             normal
#
#                                              indication  \
# 0                                      positive tb test
# 1                               preop bariatric surgery
# 2     rib pain after a steps this pain to r back r e...
# 3                                                 with
# 4                            chest and nasal congestion
# ...                                                 ...
# 3908             nausea vomiting weeks dialysis patient
# 3909                                                NaN
# 3910                             male with positive ppd
# 3911                          tuberculosis positive ppd
# 3912  this is a female patient with shortness of breath
#
#                                                findings  \
# 0     the cardiac silhouette and mediastinum size ar...
# 1     borderline cardiomegaly midline sternotomy enl...
# 2                                                   NaN
# 3     there are diffuse bilateral interstitial and a...
# 4     the cardiomediastinal silhouette and pulmonary...
# ...                                                 ...
# 3908  the cardiomediastinal silhouette and pulmonary...
# 3909  the lungs are clear heart size is normal no pn...
# 3910  heart size within normal limits small nodular ...
# 3911                                                NaN
# 3912                                                NaN
#
#                                              impression
# 0                                         normal chest
# 1                           no acute pulmonary findings
# 2     no displaced rib fractures pneumothora or pleu...
# 3      bullous emphysema and interstitial fibrosis p...
# 4                  no acute cardiopulmonary abnormality
# ...                                                 ...
# 3908   interval resolution of bibasilar airspace dis...
# 3909  clear lungs no acute cardiopulmonary abnormality
# 3910        no acute findings no evidence for active tb
# 3911       heart size is normal and the lungs are clear
# 3912  the cardiac silhouette is normal in size and c...
#
# [3913 rows x 7 columns]
